# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../src')

# %%
# from etl.pipeline_deleting_fass import delete_file_in_vector_store

# %%
help(Pinecone)
# Out:
# Help on class Pinecone in module langchain_community.vectorstores.pinecone:
#
# class Pinecone(langchain_core.vectorstores.VectorStore)
#  |  Pinecone(index: 'Any', embedding: 'Union[Embeddings, Callable]', text_key: 'str', namespace: 'Optional[str]' = None, distance_strategy: 'Optional[DistanceStrategy]' = <DistanceStrategy.COSINE: 'COSINE'>)
#  |
#  |  `Pinecone` vector store.
#  |
#  |  To use, you should have the ``pinecone-client`` python package installed.
#  |
#  |  Example:
#  |      .. code-block:: python
#  |
#  |          from langchain_community.vectorstores import Pinecone
#  |          from langchain_community.embeddings.openai import OpenAIEmbeddings
#  |          import pinecone
#  |
#  |          # The environment should be the one specified next to the API key
#  |          # in your Pinecone console
#  |          pinecone.init(api_key="***", environment="...")
#  |          index = pinecone.Index("langchain-demo")
#  |          embeddings = OpenAIEmbeddings()
# ...

# %%
from langchain.vectorstores import Pinecone, DeepLake
import pinecone
import os
from etl.embeddings import get_vectore_store_for_query

# %%
pinecone.init(api_key=os.environ["PINECONE_API_KEY"],
                      environment=os.environ["PINECONE_ENV"])

# %%
vector_store = await get_vectore_store_for_query(index_name = 'mvp-test3', model_embedding = 'hf', vector_store_client = 'pinecone', namespace = 'hf-384-2')
# Out:
# C:\Users\LP00035\AppData\Local\Temp\ipykernel_14916\478965074.py:1: RuntimeWarning: coroutine 'get_vectore_store_for_query' was never awaited
#   vector_store = await get_vectore_store_for_query(index_name = 'mvp-test3', model_embedding = 'hf', vector_store_client = 'pinecone', namespace = 'hf-384-2')
# ...

# %%
vector_store.query(filter={"source": "..\\data\\carpeta3\\Daniela Aguayo TIC.pdf"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 vector_store.query(filter={"source": "..\\data\\carpeta3\\Daniela Aguayo TIC.pdf"})
#
# AttributeError: 'Pinecone' object has no attribute 'query'

# %%
vector_store.delete(filter={"source": "..\\data\\carpeta3\\Daniela Aguayo TIC.pdf"})
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 vector_store.delete(filter={"source": "..\\data\\carpeta3\\Daniela Aguayo TIC.pdf"})
#
# File c:\Users\LP00035\anaconda3\envs\openai\lib\site-packages\langchain_community\vectorstores\pinecone.py:473, in Pinecone.delete(self, ids, delete_all, namespace, filter, **kwargs)
#     471         self._index.delete(ids=chunk, namespace=namespace, **kwargs)
#     472 elif filter is not None:
# --> 473     self._index.delete(filter=filter, namespace=namespace, **kwargs)
#     474 else:
#     475     raise ValueError("Either ids, delete_all, or filter must be provided.")
#
# File c:\Users\LP00035\anaconda3\envs\openai\lib\site-packages\pinecone\core\utils\error_handling.py:17, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
# ...

# %%
# from etl.pipeline_deleting_fass import delete_file_in_vector_store
# from etl.pipeline_upserting_fass import add_file_in_vector_store

# %%
from langchain.indexes import SQLRecordManager, index

# %%
import os
from dotenv import load_dotenv
load_dotenv('../.env')
# Out:
# True

# %%
password = os.environ['AZURE_DB_LLM_KEY']

# %%
import pyodbc
from sqlalchemy import create_engine
import urllib

params = urllib.parse.quote_plus(r'Driver={ODBC Driver 18 for SQL Server};Server=tcp:server-demo-llm.database.windows.net,1433;Database=db-demo-llm;Uid=sebas-llm;Pwd=' + password + r';Encrypt=yes;TrustServerCertificate=no;Connection Timeout=30;')
conn_str = 'mssql+pyodbc:///?odbc_connect={}'.format(params)
engine_azure = create_engine(conn_str,echo=True)

# %%
record_manager = SQLRecordManager(
    "deeplake/mvp-test", engine = engine_azure
)

# %%
record_manager.create_schema()
# Out:
# 2023-12-27 22:08:42,756 INFO sqlalchemy.engine.Engine SELECT CAST(SERVERPROPERTY('ProductVersion') AS VARCHAR)
# 2023-12-27 22:08:42,757 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-12-27 22:08:42,868 INFO sqlalchemy.engine.Engine SELECT schema_name()
# 2023-12-27 22:08:42,869 INFO sqlalchemy.engine.Engine [generated in 0.00081s] ()
# 2023-12-27 22:08:43,184 INFO sqlalchemy.engine.Engine SELECT CAST('test max support' AS NVARCHAR(max))
# 2023-12-27 22:08:43,185 INFO sqlalchemy.engine.Engine [generated in 0.00080s] ()
# 2023-12-27 22:08:43,286 INFO sqlalchemy.engine.Engine SELECT 1 FROM fn_listextendedproperty(default, default, default, default, default, default, default)
# 2023-12-27 22:08:43,286 INFO sqlalchemy.engine.Engine [generated in 0.00077s] ()
# 2023-12-27 22:08:43,486 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-12-27 22:08:43,498 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# ...
